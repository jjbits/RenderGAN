# %%
# pytorch pix2pix test module wrapper

# %%
import os
os.chdir('/Volumes/Data/projects/cs230/Project/pix2pix/pytorch-CycleGAN-and-pix2pix')

# %%
# !ls checkpoints/
# Out:
# 10-10000                       facades_label2photo_pretrained
# 10-10000-no-dropout            facades_pix2pix
# 5-5000                         plane995_pix2pix
# antics1000                     planes6664_pix2pix
# antics5000

# %%
# !python test.py --dataroot ./datasets/antics1000/AB --direction AtoB --model pix2pix --name antics1000 --gpu_ids -1
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: ./datasets/antics1000/AB      	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: -1                            	[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
# ...

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/antics1000/test_latest/images/40_fake_B.png')
plt.imshow(img)

# %%
img = plt.imread('./results/antics1000/test_latest/images/40_real_B.png')
plt.imshow(img)

# %%
img = plt.imread('./results/antics1000/test_latest/images/40_real_A.png')
plt.imshow(img)

# %%
# !python test.py --dataroot ./datasets/antics5000/AB --direction AtoB --model pix2pix --name antics5000 --gpu_ids -1
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: ./datasets/antics5000/AB      	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: -1                            	[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
# ...

# %%
# !python test.py --dataroot ./datasets/antics5000/AB --direction AtoB --model pix2pix --name 5-5000 --gpu_ids -1
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: ./datasets/antics5000/AB      	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: -1                            	[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
# ...

# %%
# !python test.py --dataroot ./datasets/antics5000/AB --direction AtoB --model pix2pix --name 10-10000 --gpu_ids -1
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: ./datasets/antics5000/AB      	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: -1                            	[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
# ...

# %%
# !python test.py --dataroot ./datasets/antics5000/AB --direction AtoB --model pix2pix --name 10-10000-no-dropout --gpu_ids -1
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: ./datasets/antics5000/AB      	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: -1                            	[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
# ...

# %%
# !python test.py --dataroot ./datasets/antics5000/AB --direction AtoB --model pix2pix --name final --gpu_ids -1
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: ./datasets/antics5000/AB      	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: -1                            	[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
# ...
